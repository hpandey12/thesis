# %%
import pandas
import matplotlib.pyplot as plt
import numpy
import os

# %%
df = numpy.genfromtxt(r"C:\Users\harsh\Documents\thesis\output_poisson.csv", delimiter= ',', dtype= float)

# %%
df
# Out:
# array([[            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan],
#        [ 1.08483082e+02,  0.00000000e+00,  0.00000000e+00,
#          5.85937500e-03,  0.00000000e+00,  1.00000000e+00,
#          1.00000001e-01,  0.00000000e+00],
#        [ 1.49519866e+02,  1.50000000e+02,  1.35450000e+05,
#          1.56250000e-02,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [ 1.47365382e+02,  1.46677504e+02,  1.32449787e+05,
#          2.44140625e-03,  8.94517942e+01,  9.00000000e-01,
#          1.00000001e-01,  0.00000000e+00],
#        [ 5.37485949e+01,  0.00000000e+00,  0.00000000e+00,
#         -1.95312500e-03,  0.00000000e+00,  1.00000000e+00,
#          2.00000003e-01,  0.00000000e+00],
#        [ 8.60914335e+01,  8.42728806e+01,  7.60984111e+04,
#         -4.88281250e-04,  4.31803906e+01,  9.00000000e-01,
# ...

# %%
# Outputs:
#   - node - struct - contains data about the nodes:
#       * X (nn x dim) - coordinates of the nodes
#       * n (n+1 x m+1) - number of nodes
#   - elem - struct - contains data about the elements:
#       * con{nel} - connectivity of the element
#       * n (1 x 1) - number of elements
#   - epro {nel} - struct - contains data of element properties:
#       * p (1 x 1) - order of the elements

class mesh():
    def __init__(self, xx, yy, val):
        self.node = {'xx': xx,
                     'yy': yy}
        self.elem = {}

    def def_elem(self):
# Out:
#      RMS of Temperature (K)  Temperature (K)  Total Energy (J/kg)  \
# 0                108.483082         0.000000             0.000000
# 1                149.519866       150.000000        135450.000000
# 2                147.365382       146.677504        132449.787109
# 3                 53.748595         0.000000             0.000000
# 4                 86.091434        84.272881         76098.411133
# ..                      ...              ...                  ...
# 116              242.503901       300.000000        270900.000000
# 117              267.197562       300.000000        270900.000000
# 118              260.442612       300.000000        270900.000000
# 119              242.495108       300.000000        270900.000000
# 120              149.518967       150.000000        135450.000000
#
#      Energy Residual (W)  L2 Error (K)  X (m)  Y (m)  Z (m)
# 0               0.005859      0.000000    1.0    0.1      0
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(xx, yy, c=df['Temperature (K)'], cmap='viridis', marker='o', edgecolor='k')

# Add labels and title
plt.xlabel('X (m)')
plt.ylabel('Y (m)')
plt.title('Scatter Plot of X vs Y')

# Show the plot
plt.show()

# %%
mesh_file_path = r"C:\Users\harsh\Documents\thesis\poisson_cel.txt"

# %%
mesh_data = numpy.loadtxt(mesh_file_path, skiprows= 2, dtype= float)

# %%
mesh_data
# Out:
# array([[ 1. ,  1. ,  0. ,  0. ],
#        [ 2. ,  1. ,  0.1,  0. ],
#        [ 3. ,  1. ,  0.2,  0. ],
#        [ 4. ,  1. ,  0.3,  0. ],
#        [ 5. ,  1. ,  0.4,  0. ],
#        [ 6. ,  1. ,  0.5,  0. ],
#        [ 7. ,  1. ,  0.6,  0. ],
#        [ 8. ,  1. ,  0.7,  0. ],
#        [ 9. ,  1. ,  0.8,  0. ],
#        [10. ,  1. ,  0.9,  0. ],
#        [11. ,  1. ,  1. ,  0. ],
#        [12. ,  1. ,  1. ,  0. ],
#        [13. ,  0.9,  1. ,  0. ],
#        [14. ,  0.8,  1. ,  0. ],
#        [15. ,  0.7,  1. ,  0. ],
#        [16. ,  0.6,  1. ,  0. ],
#        [17. ,  0.5,  1. ,  0. ],
#        [18. ,  0.4,  1. ,  0. ],
#        [19. ,  0.3,  1. ,  0. ],
#        [20. ,  0.2,  1. ,  0. ],
#        [21. ,  0.1,  1. ,  0. ],
#        [22. ,  0. ,  1. ,  0. ],
#        [23. ,  0. ,  0.1,  0. ],
#        [24. ,  0. ,  0. ,  0. ],
#        [25. ,  0. ,  0.2,  0. ],
#        [26. ,  0. ,  0.3,  0. ],
#        [27. ,  0. ,  0.4,  0. ],
#        [28. ,  0. ,  0.5,  0. ],
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(mesh_data[:, 1], mesh_data[:, 2], marker='o', edgecolor='k')

# Add labels and title
plt.xlabel('X (m)')
plt.ylabel('Y (m)')
plt.title('Scatter Plot of X vs Y')

# Show the plot
plt.show()
